# %% [markdown]
#     1.Explain the basic structure of an HTML page. Why is it important to follow this structure?
#  Answer-
#  <!DOCTYPE html>
# <html>
#   <head>
#     <title>Page Title</title>
#   </head>
#   <body>
#     <h1>Welcome to My Website</h1>
#     <p>This is a paragraph of text.</p>
#   </body>
# </html>
#
#     important to follow the structure because-
# a]Browser compatibility -Helps web browsers understand and render the page correctly.
# b]Readability-Make it easy for  developers to use,see and maintain the code.
# c]SEO and accessibility
# d]Standardization-Ensuring your sites woIt is irk on all modern devices and browsers.
# e]Avoid Errors
#
# 2.Your are building a small profile page.Which HTML tags will you use to highlight your name as a heading and describe yourself in a paragraph and emphasize a key skill?
# Answer-<!DOCTYPE html>
# <html>
#   <head>
#     <title>My Profile</title>
#   </head>
#   <body>
#     <h1>Hithaishini C.</h1>
#
#     <p>
#       I am a passionate student learning web development.
#       I enjoy creating websites and exploring new technologies.
#       One of my key skills is <strong>problem-solving</strong>,
#       which helps me tackle challenges efficiently.
#     </p>
#   </body>
# </html>
#
# 3.Look at the code below.Can you find and fix the mistake.
# <--This an html comment
#  <h1>Welcome to my website</h1>
# Answer-The comment syntax is incorrect
#        Missing comment is ! and - ->
#
# Correct code-
# <!-- This is an HTML comment -->
# <h1>Welcome to my website</h1>
#
#
# 4.Your are creating a form that asks the user to enter their name,select a country from the list and click a button to submit.Write the HTML code for this
# Answer-<!DOCTYPE html>
# <html>
#  <head>
#     <title>User Form</title>
#   </head>
#   <body>
#
#     <h2>User Information Form</h2>
#
#     <form action="#" method="post">
#      <label for="name">Name:</label>
#       <input type="text" id="name" name="name" required><br><br>
#
#       <!-- Country Selection -->
#       <label for="country">Select your country:</label>
#       <select id="country" name="country" required>
#         <option value="">--Select--</option>
#         <option value="India">India</option>
#         <option value="USA">USA</option>
#         <option value="UK">UK</option>
#         <option value="Canada">Canada</option>
#       </select><br><br>
#
#       <!-- Submit Button -->
#       <button type="submit">Submit</button>
#     </form>
#
#   </body>
# </html>
#
#
#  5.Write short HTML code to show your favourite fruits in a bulleted list and your top 3 programming languages in a numbered list
# Answer-<!DOCTYPE html>
# <html>
# <head>
#   <title>My Favorites</title>
# </head>
# <body>
#
#   <h2>My Favourite Fruits</h2>
#   <ul>
#     <li>Mango</li>
#     <li>Strawberry</li>
#     <li>Banana</li>
#   </ul>
#
#   <h2>Top 3 Programming Languages</h2>
#   <ol>
#     <li>Python</li>
#     <li>JavaScript</li>
#     <li>Java</li>
#   </ol>
#
# </body>
# </html>
#
#  6.Ravi wants to leave a note in his html file so that only other developers can see it,not the users on the website.How should he do this?Why are such notes useful
# Answer-
#      <!-- TODO: Add a contact form here later -->
#          <h1>Welcome to Ravi's Website</h1>
#
# Notes useful because-
# a]Explain complex code to other developers understand it
# b]Leave remainders for future changes or improvements
# c]Temporarily disable code without deleting it
#
# 7.Here is a form snippet.Can you spot the error and rewrite the correct version
#  <form>
#  <input name="email">
#  <select>
#  <option>Indian</option>
#   </select>
# <button>Send</buton>
#  </form>
# Answer-Yes,snippet has two errors.
# The <input> tag is missing in the type attribute
# The coding tag of the <button> is misspelled as <buton>
#
# Correct version-
#  <form>
# <input type="email" name="email">
#   <select>
#     <option>Indian</option>
#   </select>
#   <button>Send</button>
# </form>
